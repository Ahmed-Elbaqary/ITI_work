# %% [markdown]
# # Ahmed Abd-Elsalam Muhammed Afify
#
# ## Optimization Labs And HomeWorks:

# %%
# Importing Required Libraries:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1) Loading the data:
x = np.random.normal(10,4,1000).reshape(-1,1)
y = -2*x + 1

# %%
print(x[:10].T)
print(y[:10].T)
# Out:
# [[ 8.77257331 16.48796843  7.45540536  6.08248668  8.80133113  9.38942713
#   13.53402232  8.91693472 14.69683868  7.00473613]]
# [[-16.54514662 -31.97593685 -13.91081072 -11.16497336 -16.60266226
#   -17.77885426 -26.06804465 -16.83386944 -28.39367737 -13.00947225]]

# %%
# plotting data points:
plt.scatter(x, y, label='data points')
plt.xlabel('X_data')
plt.ylabel('Y_data')
plt.title('Insurance_In_Sweden')
plt.legend()
plt.show()

# %% [markdown]
# ___
# ## Momentum_based Gradient Descent:

# %%
# 2) Implementing the Momentum_Based GD:

# initialize the parameters:
m = len(x)
Xs = np.concatenate((np.ones((m,1)), x), axis=1)
thetas = np.ones((Xs.shape[1],1))
yhat = np.zeros((m,1))

# Hyper_parameters:
alpha = 0.01
gamma = 0.5
vt = np.ones((Xs.shape[1],1))
epoches = 10

# Lists to store values of epoches:
loss_lst = []
theta_0 = []
theta_1 = []
yhat_lst = []

# Implementing Iterations:
for i in range(epoches):
    yhat = Xs@ thetas
    error = yhat - y
    J_loss = (1/(2*m)) * np.sum(error**2)
    grd = (1/m) * (Xs.T @ error).reshape(-1,1)
    vt = (gamma*vt) + alpha*grd
    thetas = thetas - vt

    loss_lst.append(J_loss)
    theta_0.append(thetas[0])
    theta_1.append(thetas[1])
    yhat_lst.append(yhat)

# %%
# Printing the finale values if thetas:
print(f'theta_0 = {thetas[0]}')
print(f'theta_1 = {thetas[1]}')
# Out:
# theta_0 = [-0.13635556]
# theta_1 = [-1.84572818]

# %%
# calculating the final Hypothesis based on final theta values:
yhat = (Xs @ thetas)

# %%
# Plotting the Loss_Function during optimization:
plt.plot(loss_lst)

plt.xlabel('Iterations')
plt.ylabel('Loss_Function')
plt.title('Loss_function optimization')
plt.grid()
plt.show()

# %%
# Plotting All regression lines of all epoches versus data points:
plt.scatter(x,y, label='data points')
for i in range(epoches-1):
    plt.plot(x,yhat_lst[i], color='r')
plt.plot(x,yhat_lst[i+1], label='fit line', color='r')

plt.xlabel('Iterations')
plt.ylabel('Y_predicted')
plt.title('Values of Y_predicted')
plt.legend()
plt.show()

# %%
# Plotting the best fit regression lines of all epoches versus data points:
plt.scatter(x,y, label='data points')
plt.plot(x,yhat, label='fit line', color='r')

plt.xlabel('Iterations')
plt.ylabel('Y_predicted')
plt.title('Values of Y_predicted')
plt.legend()
plt.grid()
plt.show()

# %%
# plotting the value of theta_0 based on the loss_function optimization:
plt.plot(theta_0, loss_lst)

plt.xlabel('Theta_0')
plt.ylabel('Loss_Function')
plt.title('Theta_0 values VS. Loss_Function optimization')
plt.grid()
plt.show()

# %%
# plotting the value of theta_1 based on the loss_function optimization:
plt.plot(theta_1, loss_lst)

plt.xlabel('Theta_1')
plt.ylabel('Loss_Function')
plt.title('Theta_1 values VS. Loss_Function optimization')
plt.grid()
plt.show()

# %%
# Calculating goodness of fit of the line:
ybar = np.mean(y)
SStot = np.sum((y-ybar)**2)
SSres = np.sum((y-yhat)**2)
R2 = 1 - (SSres/SStot)
print(f'R-Squared (R2)= {R2}')
# Out:
# R-Squared (R2)= 0.9918820273554388

# %% [markdown]
# ___
# ## Nestrove_Accelerated Gradient Descent (NAG):

# %%
# 2) Implementing the Nestrove_Accelerated GD:

# initialize the parameters:
m = len(x)
Xs = np.concatenate((np.ones((m,1)), x), axis=1)
thetas = np.ones((Xs.shape[1],1))
yhat = np.zeros((m,1))

# Hyper_parameters:
alpha = 0.01
gamma = 0.5
vt = np.ones((Xs.shape[1],1))
epoches = 50

# Lists to store values of epoches:
loss_lst = []
theta_0 = []
theta_1 = []
yhat_lst = []

# Implementing Iterations:
for i in range(epoches):
    thetas_temp = thetas - vt
    yhat = Xs@ thetas_temp
    error = yhat - y
    J_loss = (1/(2*m)) * np.sum(error**2)
        
    grd = (1/m) * (Xs.T @ error).reshape(-1,1)
    thetas = thetas_temp - alpha*grd
    vt = (gamma*vt) + alpha*grd

    loss_lst.append(J_loss)
    theta_0.append(thetas[0])
    theta_1.append(thetas[1])
    yhat_lst.append(yhat)

# %%
# Printing the finale values if thetas:
print(f'theta_0 = {thetas[0]}')
print(f'theta_1 = {thetas[1]}')
# Out:
# theta_0 = [-0.6934642]
# theta_1 = [-1.84861143]

# %%
# calculating the final Hypothesis based on final theta values:
yhat = (Xs @ thetas)

# %%
# Plotting the Loss_Function during optimization:
plt.plot(loss_lst)

plt.xlabel('Iterations')
plt.ylabel('Loss_Function')
plt.title('Loss_function optimization')
plt.grid()
plt.show()

# %%
# Plotting All regression lines of all epoches versus data points:
plt.scatter(x,y, label='data points')
for i in range(epoches-1):
    plt.plot(x,yhat_lst[i], color='r')
plt.plot(x,yhat_lst[i+1], label='fit line', color='r')

plt.xlabel('Iterations')
plt.ylabel('Y_predicted')
plt.title('Values of Y_predicted')
plt.legend()
plt.show()

# %%
# Plotting the best fit regression lines of all epoches versus data points:
plt.scatter(x,y, label='data points')
plt.plot(x,yhat, label='fit line', color='r')

plt.xlabel('Iterations')
plt.ylabel('Y_predicted')
plt.title('Values of Y_predicted')
plt.legend()
plt.grid()
plt.show()

# %%
# plotting the value of theta_0 based on the loss_function optimization:
plt.plot(theta_0, loss_lst)

plt.xlabel('Theta_0')
plt.ylabel('Loss_Function')
plt.title('Theta_0 values VS. Loss_Function optimization')
plt.grid()
plt.show()

# %%
# plotting the value of theta_1 based on the loss_function optimization:
plt.plot(theta_1, loss_lst)

plt.xlabel('Theta_1')
plt.ylabel('Loss_Function')
plt.title('Theta_1 values VS. Loss_Function optimization')
plt.grid()
plt.show()

# %%
# Calculating goodness of fit of the line:
ybar = np.mean(y)
SStot = np.sum((y-ybar)**2)
SSres = np.sum((y-yhat)**2)
R2 = 1 - (SSres/SStot)
print(f'R-Squared (R2)= {R2}')
# Out:
# R-Squared (R2)= 0.9605439753316786
